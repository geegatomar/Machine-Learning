# %% [markdown]
# ## K-Means Clustering

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(centers=3)

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=3)
preds = model.fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=preds)

# %%
model = KMeans(n_clusters=4)
preds = model.fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=preds)

# %%
# K-Means depends on n_clusters specified by the user
# Also it doesnt work for more complex shaped clusters

# %% [markdown]
# ## Agglomerative Clustering

# %%
from sklearn.cluster import AgglomerativeClustering

model = AgglomerativeClustering(n_clusters=3)
preds = model.fit_predict(X)
plt.scatter(X[:, 0], X[: ,1], c=preds)

# %%
from sklearn.datasets import make_moons

X, y = make_moons(noise=.02)

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
kmeans = KMeans(n_clusters=2)
pred = kmeans.fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=pred)

# %%
# K-Means gave wrong prediction for the moons

# %%
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

agg = AgglomerativeClustering(n_clusters=2)
pred = agg.fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=pred)

# %%
from sklearn.metrics import adjusted_rand_score

adjusted_rand_score(y, pred)
# Out:
# 0.6065184066117171

# %% [markdown]
# ## DBSCAN

# %%
X, y = make_moons(n_samples=200, noise=0.05, random_state=0)

from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

dbs = DBSCAN()
pred = dbs.fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=pred)

# %%
from sklearn.metrics import adjusted_rand_score

adjusted_rand_score(y, pred)
# Out:
# 1.0

# %%
import numpy as np
np.unique(pred)
# Out:
# array([0, 1])

# %%
# parameters to adjust in DBSCAN are eps and min_samples
